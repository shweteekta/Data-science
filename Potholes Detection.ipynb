# %%
# !wget -O acc.txt https://raw.githubusercontent.com/shweteekta/College-Project/master/ACC
# Out:
# --2019-12-23 09:33:59--  https://raw.githubusercontent.com/shweteekta/College-Project/master/ACC
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1276435 (1.2M) [text/plain]
# Saving to: ‘acc.txt’
#
# 100%[======================================>] 1,276,435   --.-K/s   in 0.05s
#
# 2019-12-23 09:33:59 (25.9 MB/s) - ‘acc.txt’ saved [1276435/1276435]

# %%
# !wget -O gyro.txt https://raw.githubusercontent.com/shweteekta/College-Project/master/GYRO
# Out:
# --2019-12-23 09:34:26--  https://raw.githubusercontent.com/shweteekta/College-Project/master/GYRO
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 805539 (787K) [text/plain]
# Saving to: ‘gyro.txt’
#
# 100%[======================================>] 805,539     --.-K/s   in 0.03s
#
# 2019-12-23 09:34:27 (22.0 MB/s) - ‘gyro.txt’ saved [805539/805539]

# %%
# !ls
# Out:
# acc.txt  gyro.txt

# %%
import pandas as pd
df = pd.read_fwf('acc.txt')
df.to_csv('log.csv')
df1 = pd.read_fwf('gyro.txt')
df1.to_csv('log1.csv')

# %%
acc=pd.read_csv("log.csv")
gyro=pd.read_csv("log1.csv")

# %%
acc
# Out:
#        Unnamed: 0                             "X","Y","Z","Sequence"
# 0               0  "-0.24062547087669373","5.265261650085449","8....
# 1               1  "-0.23822999000549316","5.23651647567749","8.1...
# 2               2  "-0.23822999000549316","5.214956760406494","8....
# 3               3  "-0.35560840368270874","5.198188304901123","8....
# 4               4  "-0.477777898311615","5.231725215911865","8.27...
# 5               5  "-0.26458024978637695","5.179024696350098","8....
# 6               6  "-0.26458024978637695","5.202979564666748","8....
# 7               7  "-0.16157469153404236","5.179024696350098","8....
# 8               8  "-0.31488531827926636","5.485645771026611","7....
# 9               9  "-0.3340491056442261","5.3922224044799805","8....
# 10             10  "-0.35321295261383057","5.265261650085449","8....
# 11             11  "-0.2549983263015747","5.123929023742676","8.6...
# 12             12  "-0.21187976002693176","5.308380603790283","7....
# ...

# %%
gyro.shape
# Out:
# (18135, 2)
